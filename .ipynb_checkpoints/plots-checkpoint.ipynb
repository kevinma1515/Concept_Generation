# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## RQ 1:
#
# How do parameters such as temperature and Top P affect the diversity of the generated text output?

# %%
# DPP calculations
data = [
[-24, -25, -24, -25, -19, -8, -22, -24, 0, 0],
[-48, -42, -69, -48, -41, -20, -46, -33, 2, 0],
[-27, -27, -42, -30, -40, -20, -53, -43, 0, 0],
[-36, -25, -41, -22, -30, -5, -20, -50, 0, 0],
[-26, -28, -23, -16, -14, -6, -23, -14, -6, 0]
]

# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['froth', 'towels', 'time', 'powder', 'exercise', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]
sns.set_context("notebook")

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Design Topics')
plt.title('RQ1 DPP Comparison with Mean')
plt.tight_layout()

# Custom annotations for the last row
custom_colors = ['white', 'white', 'black', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(8.9)', '\n\n(6.4)', '\n\n(16.7)', '\n\n(10.9)', '\n\n(10.9)', '\n\n(6.8)', '\n\n(13.8)', '\n\n(12.9)', '\n\n(2.7)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Variance')
plt.title('RQ1 DPP Standard Deviation')
plt.tight_layout()
plt.show()

# %%
# Nearest Generated Distance
data = [
    [-18, -19, -19, -21, -20, -12, -15, -21, -2, 0],
    [-38, -38, -48, -36, -33, -24, -35, -31, 3, 0],
    [-14, -14, -20, -18, -23, -16, -30, -22, 1, 0],
    [-26, -18, -27, -17, -19, -7, -16, -34, 0, 0],
    [-9, -8, -7, -4, -5, -4, -7, -5, -2, 0]
]

# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['froth', 'towels', 'time', 'powder', 'exercise', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]
sns.set_context("notebook")

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Design Topics')
plt.title('RQ1 Nearest Generated Distance Comparison with Mean')
plt.tight_layout()

# Custom annotations for the last row
custom_colors = ['white', 'white', 'black', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(10.2)', '\n\n(10.1)', '\n\n(13.5)', '\n\n(10.2)', '\n\n(9.0)', '\n\n(7.0)', '\n\n(10.3)', '\n\n(10.1)', '\n\n(1.9)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Variance')
plt.title('RQ1 Nearest Generated Distance Standard Deviation')
plt.tight_layout()
plt.show()

# %%
# Convex Hull
data = [
    [-94, -94, -94, -96, -97, -88, -87, -97, -34, 0],
    [-100, -100, -100, -100, -100, -98, -100, -100, 26, 0],
    [-93, -91, -96, -96, -98, -95, -99, -97, -12, 0],
    [-99, -96, -99, -94, -96, -72, -94, -100, 32, 0],
    [-74, -68, -67, -37, -57, -46, -66, -63, -19, 0]
]
# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['froth', 'towels', 'time', 'powder', 'exercise', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]
sns.set_context("notebook")

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Design Topics')
plt.title('RQ1 Convex Hull Comparison with Mean')
plt.tight_layout()
# Custom annotations for the last row
custom_colors = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'white', 'white']
custom_annotations = ['\n\n(9.4)', '\n\n(11.3)', '\n\n(12.3)', '\n\n(23.9)', '\n\n(16.4)', '\n\n(19.1)', '\n\n(12.5)', '\n\n(14.3)', '\n\n(25.9)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Variance')
plt.title('RQ1 Convex Hull Standard Deviation')
plt.tight_layout()
plt.show()

# %%
# Centroid Distance
data = [
    [-17, -18, -18, -21, -22, -12, -12, -21, -3, 0],
    [-38, -40, -48, -36, -33, -27, -34, -33, 2, 0],
    [-12, -13, -17, -18, -22, -17, -30, -21, 1, 0],
    [-26, -18, -27, -16, -18, -8, -17, -34, 1, 0],
    [-5, -4, -3, -1, -3, -3, -3, -3, -1, 0]
]
# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['froth', 'towels', 'time', 'powder', 'exercise', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]
sns.set_context("notebook")
# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Design Topics')
plt.title('RQ1 Centroid Distance Comparison with Mean')
plt.tight_layout()
# Custom annotations for the last row
custom_colors = ['white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(11.5)', '\n\n(11.9)', '\n\n(14.8)', '\n\n(11.2)', '\n\n(9.7)', '\n\n(8.2)', '\n\n(11.4)', '\n\n(11.2)', '\n\n(0.0)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('')
plt.title('RQ1 Centroid Distance Standard Deviation')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RQ 2
# How does styling of the input prompt impact the output diversity of the prompt?

# %%
# DPP Calculations
data = [
[-20, -8, -13, -23, -1, -21, -2, 0, 2, 0],
[-5, -16, -10, -10, -5, -14, 0, 4, 0, 0],
[-20, -8, -13, -16, -21, -22, -25, -14, 0, 0],
[-6, -6, -3, -10, -6, -2, -3, 1, -6, 0],
[-8, -10, -6, -8, -7, -5, -8, -5, 0, 0]
]

# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['towels', 'powder', 'time', 'exercise', 'froth', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'zero-shot',
    'few-shot',
    'novel',
    'unique',
    'creative',
    'design-expert',
    'farfetched',
    'critique',
    'human-1',
    'human-2'
]

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Prompt Engineering')
plt.ylabel('Design Topics')
plt.title('RQ2 DPP Comparison with Mean')
plt.tight_layout()

# Custom annotations for the last row
custom_colors = ['black', 'white', 'white', 'black', 'white', 'black', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(6.8)', '\n\n(3.4)', '\n\n(3.9)', '\n\n(5.5)', '\n\n(6.8)', '\n\n(8.1)', '\n\n(9.1)', '\n\n(6.3)', '\n\n(2.7)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('')
plt.title('RQ2 DPP Standard Deviation')
plt.tight_layout()
plt.show()

# %%
# Nearest Generated Distance Calculations
data = [
    [-24, -15, -17, -24, -10, -22, -9, -8, 3, 0],
    [-7, -11, -10, -10, -7, -12, -4, 1, 0, 0],
    [-16, -9, -11, -11, -16, -17, -18, -13, 1, 0],
    [-4, -4, -2, -5, -4, -3, -5, -2, -2, 0],
    [-12, -13, -12, -11, -12, -9, -11, -9, -2, 0]
]
# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['towels', 'powder', 'time', 'exercise', 'froth', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'zero-shot',
    'few-shot',
    'novel',
    'unique',
    'creative',
    'design-expert',
    'farfetched',
    'critique',
    'human-1',
    'human-2'
]
sns.set_context("notebook")

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Prompt Engineering')
plt.ylabel('Design Topics')
plt.title('RQ2 Nearest Generated Distance Comparison with Mean')
plt.tight_layout()

# Custom annotations for the last row
custom_colors = ['black', 'white', 'white', 'black', 'white', 'black', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(7.0)', '\n\n(3.8)', '\n\n(4.8)', '\n\n(6.3)', '\n\n(4.1)', '\n\n(6.5)', '\n\n(5.0)', '\n\n(5.0)', '\n\n(1.9)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])
    
plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Variance')
plt.title('RQ2 Nearest Generated Distance Standard Deviation')
plt.tight_layout()
plt.show()

# %%
# Convex Hull Calculations
data = [
    [-98, -94, -95, -98, -84, -97, -87, -82, 26, 0],
    [-72, -84, -77, -80, -77, -85, -53, -27, 32, 0],
    [-95, -84, -86, -86, -95, -95, -96, -93, -12, 0],
    [-46, -46, -45, -55, -54, -47, -65, -19, -54, 0],
    [-88, -87, -87, -86, -90, -79, -78, -80, -34, 0]
]
# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['towels', 'powder', 'time', 'exercise', 'froth', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'zero-shot',
    'few-shot',
    'novel',
    'unique',
    'creative',
    'design-expert',
    'farfetched',
    'critique',
    'human-1',
    'human-2'
]
sns.set_context("notebook")

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Prompt Engineering')
plt.ylabel('Design Topics')
plt.title('RQ2 Convex Hull Comparison with Mean')
plt.tight_layout()

# Custom annotations for the last row
custom_colors = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'white', 'white']
custom_annotations = ['\n\n(19.1)', '\n\n(16.9)', '\n\n(17.5)', '\n\n(14.3)', '\n\n(14.3)', '\n\n(18.0)', '\n\n(15.3)', '\n\n(30.8)', '\n\n(33.4)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()

# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Variance')
plt.title('RQ2 Convex Hull Standard Deviation')
plt.tight_layout()
plt.show()

# %%
# Centroid Distance
data = [
    [-27, -19, -20, -27, -13, -23, -12, -11, 2, 0],
    [-8, -10, -10, -11, -8, -11, -5, 1, 1, 0],
    [-17, -10, -11, -11, -16, -18, -18, -15, 1, 0],
    [-3, -4, -2, -4, -3, -2, -5, -3, -1, 0],
    [-12, -14, -13, -11, -14, -9, -12, -10, -3, 0]
]
# Calculate the mean and variance for each column
mean_values = np.mean(data, axis=0)
variance_values = np.std(data, axis=0)

# Append the mean to the data list
data_with_mean = data + [mean_values]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['towels', 'powder', 'time', 'exercise', 'froth', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'zero-shot',
    'few-shot',
    'novel',
    'unique',
    'creative',
    'design-expert',
    'farfetched',
    'critique',
    'human-1',
    'human-2'
]
sns.set_context("notebook")

# Heatmap with mean values
plt.figure(figsize=(10, 7))  # Adjust the size as needed
ax = sns.heatmap(data_with_mean, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Prompt Engineering')
plt.ylabel('Design Topics')
plt.title('RQ2 Centroid Distance Comparison with Mean')
plt.tight_layout()
# Custom annotations for the last row
custom_colors = ['black', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(8.2)', '\n\n(5.0)', '\n\n(5.8)', '\n\n(7.6)', '\n\n(4.7)', '\n\n(7.3)', '\n\n(4.9)', '\n\n(5.8)', '\n\n(1.8)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax.text(i + 0.5, len(data_with_mean) - 0.5, annotation, ha='center', va='center', color = custom_colors[i])

plt.show()
# Heatmap with variance values
plt.figure(figsize=(10, 3))  # Adjust the size as needed
sns.heatmap([variance_values], annot=True, fmt=".1f", yticklabels=['Variance'], xticklabels=x_labels, cmap="YlGnBu")
plt.xticks(rotation=45, ha='right')
plt.xlabel('Parameters')
plt.ylabel('Variance')
plt.title('RQ2 Centroid Distance Standard Deviation')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RQ3
#
# Does the design prompt topic affect diversity?

# %%
# Convex Hull
data = [
    [-94, -100, -60, -98, 0],
    [-94, -100, -61, -95, 0],
    [-95, -100, -84, -98, 0],
    [-98, -100, -91, -95, 0],
    [-98, -100, -93, -95, 0],
    [-94, -99, -88, -77, 0],
    [-89, -100, -97, -91, 0],
    [-98, -100, -89, -100, 0],
    [-76, -58, 55, -25, 0],
    [-71, -73, 43, -54, 0]
]
# Custom y-axis labels
y_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
x_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RQ3 Convex Hull Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# DPP
data = [
    [29, 82, 0, 31, 0],
    [27, 67, -2, 12, 0],
    [34, 126, 23, 44, 0],
    [49, 109, 17, 28, 0],
    [43, 102, 36, 44, 0],
    [39, 82, 21, 19, 0],
    [31, 86, 37, 13, 0],
    [52, 86, 41, 78, 0],
    [25, 37, -10, 11, 0],
    [39, 56, 0, 22, 0]
]
# Custom y-axis labels
y_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
x_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RQ3 DPP Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Nearest Generated
data = [
    [-20, -41, -6, -24, 0],
    [-21, -41, -6, -17, 0],
    [-22, -51, -13, -27, 0],
    [-26, -42, -14, -19, 0],
    [-25, -39, -19, -21, 0],
    [-18, -31, -13, -10, 0],
    [-18, -39, -25, -16, 0],
    [-25, -37, -18, -35, 0],
    [-10, -8, 4, -4, 0],
    [-10, -13, 0, -7, 0]
]
# Custom y-axis labels
y_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
x_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RQ3 Nearest Generated Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Centroid
data = [
    [-21, -41, -6, -27, 0],
    [-22, -44, -9, -20, 0],
    [-23, -52, -13, -30, 0],
    [-28, -43, -17, -21, 0],
    [-26, -38, -19, -21, 0],
    [-18, -32, -14, -11, 0],
    [-18, -39, -27, -19, 0],
    [-27, -38, -18, -36, 0],
    [-11, -7, 3, -5, 0],
    [-9, -10, 1, -7, 0]
]
# Custom y-axis labels
y_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
x_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RQ3 Centroid Distance Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()
