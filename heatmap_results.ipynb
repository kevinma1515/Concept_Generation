# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# For RQ1

# DPP

data1 = [
[-26, -28, -23, -16, -14, -6, -23, -14, -6, 0],
[-36, -25, -41, -22, -30, -5, -20, -50, 0, 0],
[-27, -27, -42, -30, -40, -20, -53, -43, 0, 0],
[-24, -25, -24, -25, -19, -8, -22, -24, 0, 0],
[-48, -42, -69, -48, -41, -20, -46, -33, 2, 0]
]

# Calculate the mean and variance for each column
mean_values1 = np.mean(data1, axis=0)
variance_values1 = np.std(data1, axis=0)

# Append the mean to the data list
data_with_mean1 = data1 + [mean_values1]



# Nearest Generated Distance

data2 = [
[-9, -8, -7, -4, -5, -4, -7, -5, -2, 0],
[-26, -18, -27, -17, -19, -7, -16, -34, 0, 0],
[-14, -14, -20, -18, -23, -16, -30, -22, 1, 0],
[-18, -19, -19, -21, -20, -12, -15, -21, -2, 0],
[-38, -38, -48, -36, -33, -24, -35, -31, 3, 0]
]

# Calculate the mean and variance for each column
mean_values2 = np.mean(data2, axis=0)
variance_values2 = np.std(data2, axis=0)

# Append the mean to the data list
data_with_mean2 = data2 + [mean_values2]


# Convex Hull
data3 = [
   [-74, -68, -67, -37, -57, -46, -66, -63, -19, 0],
    [-99, -96, -99, -94, -96, -72, -94, -100, 32, 0],
    [-93, -91, -96, -96, -98, -95, -99, -97, -12, 0],
    [-94, -94, -94, -96, -97, -88, -87, -97, -34, 0],
    [-100, -100, -100, -100, -100, -98, -100, -100, 26, 0]
]

# Calculate the mean and variance for each column
mean_values3 = np.mean(data3, axis=0)
variance_values3 = np.std(data3, axis=0)

# Append the mean to the data list
data_with_mean3 = data3 + [mean_values3]


# Centroid Distance
data4 = [
   [-5, -4, -3, -1, -3, -3, -3, -3, -1, 0],
    [-26, -18, -27, -16, -18, -8, -17, -34, 1, 0],
    [-12, -13, -17, -18, -22, -17, -30, -21, 1, 0],
    [-17, -18, -18, -21, -22, -12, -12, -21, -3, 0],
    [-38, -40, -48, -36, -33, -27, -34, -33, 2, 0]
]

# Calculate the mean and variance for each column
mean_values4 = np.mean(data4, axis=0)
variance_values4 = np.std(data4, axis=0)

# Append the mean to the data list
data_with_mean4 = data4 + [mean_values4]


# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['exercise', 'powder', 'time', 'froth', 'towels', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'TopP=0|Temp=0',
    'TopP=0.5|Temp=0',
    'TopP=1|Temp=0',
    'TopP=0|Temp=1',
    'TopP=0.5|Temp=1',
    'TopP=1|Temp=1',
    'TopP=0|Temp=2',
    'TopP=0.5|Temp=2',
    'Human 50 v1',
    'Human 50 v2'
]
sns.set_context("notebook", font_scale=1.25)

# Create a figure with three subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 12))  # Adjust the size as needed


# First heatmap on the first subplot
sns.heatmap(data_with_mean1, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
ax1.set_title('RQ1 DPP Comparison with Mean (a)')
ax1.hlines(len(data1), *ax1.get_xlim(), color="black", linewidth=2)

# Second heatmap on the second subplot
sns.heatmap(data_with_mean2, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
ax2.set_title('RQ1 Nearest Generated Distance Comparison with Mean (b)')
ax2.hlines(len(data2), *ax2.get_xlim(), color="black", linewidth=2)

# Third heatmap on the third subplot
sns.heatmap(data_with_mean3, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax3)
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45, ha='right')
ax3.set_title('RQ1 Convex Hull Comparison with Mean (c)')
ax3.hlines(len(data3), *ax3.get_xlim(), color="black", linewidth=2)

# Fourth heatmap on the fourth subplot
sns.heatmap(data_with_mean4, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax4)
ax4.set_xticklabels(ax4.get_xticklabels(), rotation=45, ha='right')
ax4.set_title('RQ1 Centroid Distance Comparison with Mean (d)')
ax4.hlines(len(data4), *ax4.get_xlim(), color="black", linewidth=2)

plt.tight_layout()
plt.subplots_adjust(hspace=0.6)
fig.text(0.5, 0.001, 'Top-P/Temp (abbreviated for temperature) Parameters (x-axis label)', ha='center', va='center', fontsize=16)
fig.text(0.01, 0.5, 'Design Topic (y-axis label)', ha='center', va='center', rotation='vertical', fontsize=16)
# Custom annotations for the last row
custom_colors = ['white', 'white', 'black', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(8.9)', '\n\n(6.4)', '\n\n(16.7)', '\n\n(10.9)', '\n\n(10.9)', '\n\n(6.8)', '\n\n(13.8)', '\n\n(12.9)', '\n\n(2.7)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax1.text(i + 0.5, len(data_with_mean1) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)

custom_colors = ['white', 'white', 'black', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(10.2)', '\n\n(10.1)', '\n\n(13.5)', '\n\n(10.2)', '\n\n(9.0)', '\n\n(7.0)', '\n\n(10.3)', '\n\n(10.1)', '\n\n(1.9)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax2.text(i + 0.5, len(data_with_mean2) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)

custom_colors = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'white', 'white']
custom_annotations = ['\n\n(9.4)', '\n\n(11.3)', '\n\n(12.3)', '\n\n(23.9)', '\n\n(16.4)', '\n\n(19.1)', '\n\n(12.5)', '\n\n(14.3)', '\n\n(25.9)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax3.text(i + 0.5, len(data_with_mean3) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)
    
custom_colors = ['white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(11.5)', '\n\n(11.9)', '\n\n(14.8)', '\n\n(11.2)', '\n\n(9.7)', '\n\n(8.2)', '\n\n(11.4)', '\n\n(11.2)', '\n\n(0.0)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax4.text(i + 0.5, len(data_with_mean4) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)
    

plt.show()

# %%
# Variance calculation for means
# DPP
print("Variance for DPP RQ1:", np.std(mean_values1[0:8]))

# Nearest Generated Sample
print("Variance for NGS RQ1:", np.std(mean_values2[0:8]))

# Convex Hull
print("Variance for Convex Hull RQ1:", np.std(mean_values3[0:8]))

# Average Distance to Centroid
print("Variance for Centroid RQ1:", np.std(mean_values4[0:8]))
# Out:
# Variance for DPP RQ1: 7.505289801200217
# Variance for NGS RQ1: 3.1917863337009265
# Variance for Convex Hull RQ1: 3.9086442662386167
# Variance for Centroid RQ1: 2.6635267973121652

# %%
# RQ2

# DPP Calculations
data1 = [
    [-7, -7, -4, -10, -6, -7, -3, -3, 1, -4, 0],
    [-5, -16, -10, -10, -5,-7, -14, 0, 4, 0, 0],
    [-20, -8, -13, -16, -21, -19, -22, -25, -14, 0, 0],
    [-8, -10, -6, -8, -7, -4, -5, -8, -5, 0, 0],
    [-22, -10, -14, -25, -3, -20, -22, -3, -1, 1, 0]
]

# Calculate the mean and variance for each column
mean_values1 = np.mean(data1, axis=0)
variance_values1 = np.std(data1, axis=0)

# Append the mean to the data list
data_with_mean1 = data1 + [mean_values1]


# Nearest Generated Sample
data2 = [
    [-4, -4, -3, -6, -4, -6, -2, -4, -1, -2, 0],
    [-7, -11, -10, -10, -7, -7, -12, -4, 1, 0, 0],
    [-16, -9, -11, -11, -16, -14, -17, -18, -13, 1, 0],
    [-12, -13, -12, -11, -12, -10, -9, -11, -9, -2, 0],
    [-25, -16, -19, -26, -11, -24,  -23, -10, -9, 1, 0]
]
# Calculate the mean and variance for each column
mean_values2 = np.mean(data2, axis=0)
variance_values2 = np.std(data2, axis=0)

# Append the mean to the data list
data_with_mean2 = data2 + [mean_values2]


# Convex Hull
data3 = [
    [-46, -51, -51, -57, -57, -63, -41, -61, -51, -18, 0],
    [-72, -84, -77, -80, -77, -72, -85, -54, -27, 32, 0],
    [-95, -84, -86, -86, -95, -91, -95, -96, -92, -12, 0],
    [-88, -87, -87, -86, -90, -81, -79, -78, -80, -34, 0],
    [-99, -95, -96, -99, -88, -99, -98, -90, -86, -6, 0]
]
# Calculate the mean and variance for each column
mean_values3 = np.mean(data3, axis=0)
variance_values3 = np.std(data3, axis=0)

# Append the mean to the data list
data_with_mean3 = data3 + [mean_values3]


# Centroid Distance
data4 = [
    [-4, -4, -2, -5, -4, -5, -1, -5, -3, -1, 0],
    [-8, -10, -10, -11, -8, -7, -12, -5, 0, 1, 0],
    [-17, -10, -11, -11, -16, -13, -18, -19, -15, 1, 0],
    [-12, -14, -13, -11, -14, -12, -12, -10, -9, -3, 0],
    [-28, -20, -21, -28, -14, -26, -25, -12, -12, 1, 0]
]
# Calculate the mean and variance for each column
mean_values4 = np.mean(data4, axis=0)
variance_values4 = np.std(data4, axis=0)

# Append the mean to the data list
data_with_mean4 = data4 + [mean_values4]

# Custom y-axis labels with 'Mean' added
y_labels_with_mean = ['exercise', 'powder', 'time', 'froth', 'towels', 'Mean (std)']

# Custom x-axis labels
x_labels = [
    'zero-shot',
    'few-shot',
    'novel',
    'unique',
    'creative',
    'diverse',
    'design-expert',
    'farfetched',
    'critique',
    'Human 50 v1',
    'Human 50 v2'
]

# %%
print("std for DPP: ", variance_values1)
print("std for NGD: ", variance_values2)
print("std for convex: ", variance_values3)
print("std for centroid: ", variance_values4)
# Out:
# std for DPP:  [7.11617875 3.12409987 3.87814389 6.20966988 6.43739078 6.71118469
#  8.08455317 8.97552227 6.2289646  1.74355958 0.        ]
# std for NGD:  [7.3593478  4.02988834 5.09901951 6.85273668 4.14728827 6.52380257
#  7.11617875 5.2        5.30659966 1.356466   0.        ]
# std for convex:  [19.33907961 15.14463601 15.42206212 13.77824372 13.54400236 12.87478155
#  20.47046653 16.17899873 24.53894863 21.88698243  0.        ]
# std for centroid:  [8.3042158  5.27636238 6.08604962 7.75628777 4.48998886 7.33757453
#  7.91454357 5.19230199 5.5641711  1.6        0.        ]

# %%
sns.set_context("notebook", font_scale=1.25)


# Create a figure with three subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 12))  # Adjust the size as needed


# First heatmap on the first subplot
sns.heatmap(data_with_mean1, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
ax1.set_title('RQ2 DPP Comparison with Mean (a)')
ax1.hlines(len(data1), *ax1.get_xlim(), color="black", linewidth=2)

# Second heatmap on the second subplot
sns.heatmap(data_with_mean2, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
ax2.set_title('RQ2 Nearest Generated Distance Comparison with Mean (b)')
ax2.hlines(len(data2), *ax2.get_xlim(), color="black", linewidth=2)

# Third heatmap on the third subplot
sns.heatmap(data_with_mean3, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax3)
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45, ha='right')
ax3.set_title('RQ2 Convex Hull Comparison with Mean (c)')
ax3.hlines(len(data3), *ax3.get_xlim(), color="black", linewidth=2)

# Fourth heatmap on the fourth subplot
sns.heatmap(data_with_mean4, annot=True, fmt=".1f", yticklabels=y_labels_with_mean, xticklabels=x_labels, cmap="YlGnBu", ax=ax4)
ax4.set_xticklabels(ax4.get_xticklabels(), rotation=45, ha='right')
ax4.set_title('RQ2 Centroid Distance Comparison with Mean (d)')
ax4.hlines(len(data4), *ax4.get_xlim(), color="black", linewidth=2)

plt.tight_layout()
plt.subplots_adjust(hspace=0.5)
fig.text(0.5, 0.01, 'Prompt Engineering Method (x-axis label)', ha='center', va='center', fontsize=16)
fig.text(0.01, 0.5, 'Design Topic (y-axis label)', ha='center', va='center', rotation='vertical', fontsize=16)
# Custom annotations for the last row
custom_colors = ['black', 'white', 'white', 'black', 'white', 'black', 'black', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(7.1)', '\n\n(3.1)', '\n\n(3.9)', '\n\n(6.2)', '\n\n(6.4)', '\n\n(6.7)', '\n\n(8.1)', '\n\n(9.0)', '\n\n(6.2)', '\n\n(1.7)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax1.text(i + 0.5, len(data_with_mean1) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)
    
custom_colors = ['white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(7.4)', '\n\n(4.0)', '\n\n(5.1)', '\n\n(6.9)', '\n\n(4.1)', '\n\n(6.5)', '\n\n(7.1)', '\n\n(5.2)', '\n\n(5.3)', '\n\n(1.4)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax2.text(i + 0.5, len(data_with_mean2) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)
    
custom_colors = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'white', 'white']
custom_annotations = ['\n\n(19.3)', '\n\n(15.1)', '\n\n(15.4)', '\n\n(13.8)', '\n\n(13.5)', '\n\n(12.9)', '\n\n(20.5)', '\n\n(16.2)', '\n\n(24.5)', '\n\n(21.9)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax3.text(i + 0.5, len(data_with_mean3) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)
    
custom_colors = ['white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white', 'white']
custom_annotations = ['\n\n(8.3)', '\n\n(5.3)', '\n\n(6.1)', '\n\n(7.8)', '\n\n(4.5)', '\n\n(7.3)', '\n\n(8.0)', '\n\n(5.2)', '\n\n(5.6)', '\n\n(1.6)', '\n\n(0.0)']
for i, annotation in enumerate(custom_annotations):
    ax4.text(i + 0.5, len(data_with_mean4) - 0.5, annotation, ha='center', va='center', color = custom_colors[i], fontsize = 11)
    
plt.show()

# %%
# Variance calculation for means
# DPP
print("Variance for DPP RQ2:", np.std(mean_values1[0:8]))

# Nearest Generated Sample
print("Variance for NGS RQ2:", np.std(mean_values2[0:8]))

# Convex Hull
print("Variance for Convex Hull RQ2:", np.std(mean_values3[0:8]))

# Average Distance to Centroid
print("Variance for Centroid RQ2:", np.std(mean_values4[0:8]))
# Out:
# Variance for DPP RQ2: 3.2069260983066012
# Variance for NGS RQ2: 1.9968725547715858
# Variance for Convex Hull RQ2: 6.462971452822608
# Variance for Centroid RQ2: 1.6998161665309577
