# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, roc_curve, auc, RocCurveDisplay
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ## Milk Froth

# %%
csv_files = 'data/ablation_topic_froth.csv'

# %%
df = pd.read_csv(csv_files)

# %%
# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

# %%
new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
    
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})
    
new_df = pd.DataFrame(new_rows)

# %%
new_df['Type'].value_counts()
# Out:
# LLM-Generated      400
# human-generated    100
# Name: Type, dtype: int64

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

# %%
# separate the data based on the 'target' value
llm_data = new_df[new_df['Target']==0]
human_data = new_df[new_df['Target']==1]

# split each separately, ensuring 20% test size for each
llm_train, llm_test = train_test_split(llm_data, test_size = 0.2, random_state = 42)
human_train, human_test = train_test_split(human_data, test_size = 0.2, random_state = 42)

# combine the splits back
train_df = pd.concat([llm_train, human_train])
test_df = pd.concat([llm_test, human_test])

# extract embeddings for train and test sets
X_train = model.encode(train_df['Value'].astype('str').tolist())
X_test = model.encode(test_df['Value'].astype('str').tolist())

# %%
y_train = train_df['Target']
y_test = test_df['Target']

# %%
# Initialize and train the logistic regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = lr_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        80
#            1       1.00      0.80      0.89        20
#
#     accuracy                           0.96       100
#    macro avg       0.98      0.90      0.93       100
# weighted avg       0.96      0.96      0.96       100

# %% [markdown]
# **Classification Metrics**: The performance metrics from the `classification_report` such as accuracy, precision, recall (sensitivity), and F1-score give us a quantitative measure of how well the model is distinguishing between the two classes. High values (close to 1) indicate good separability.
#
# **Confusion Matrix**: This shows the number of true positives, true negatives, false positives, and false negatives. A model that perfectly linearly separates the data will have non-zero values only on the diagonal (true positives and true negatives). Note: [[TP, FP] [FN, TN]]. An additional note, since we define 'human-generated' as the positive class (1), then a false positive means the model incorrectly predicted a piece of text to be 'human-generated' when it was actually 'LLM-generated'. Likewise, since we define 'LLM-generated' as the negative class (0), a false negative means the model incorrectly predicted a piece of text to be 'LLM-generated' when it was actually 'human-generated'.
#
# **ROC Curve and AUC**: The Receiver Operating Characteristic (ROC) curve and the Area Under the Curve (AUC) illustrates the performance of our binary classifier model. An AUC close to 1 generally indicates near perfect separability.

# %%
# Confusion Matrix

conf_matrix = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", conf_matrix)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, lr_model.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[80  0]
#  [ 4 16]]

# %% [markdown]
# ## Exercise Device

# %%
csv_files = 'data/ablation_topic_exercise.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
        
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})

new_df = pd.DataFrame(new_rows)

# %%
# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

# separate the data based on the 'target' value
llm_data = new_df[new_df['Target']==0]
human_data = new_df[new_df['Target']==1]

# split each separately, ensuring 20% test size for each
llm_train, llm_test = train_test_split(llm_data, test_size = 0.2, random_state = 42)
human_train, human_test = train_test_split(human_data, test_size = 0.2, random_state = 42)

# combine the splits back
train_df = pd.concat([llm_train, human_train])
test_df = pd.concat([llm_test, human_test])

# extract embeddings for train and test sets
X_train = model.encode(train_df['Value'].astype('str').tolist())
X_test = model.encode(test_df['Value'].astype('str').tolist())

y_train = train_df['Target']
y_test = test_df['Target']

# Initialize and train the logistic regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = lr_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91        80
#            1       1.00      0.25      0.40        20
#
#     accuracy                           0.85       100
#    macro avg       0.92      0.62      0.66       100
# weighted avg       0.87      0.85      0.81       100

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", conf_matrix)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, lr_model.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[80  0]
#  [15  5]]

# %% [markdown]
# ## Powder

# %%
csv_files = 'data/ablation_topic_powder.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
    
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})
    
new_df = pd.DataFrame(new_rows)

# %%
# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

# separate the data based on the 'target' value
llm_data = new_df[new_df['Target']==0]
human_data = new_df[new_df['Target']==1]

# split each separately, ensuring 20% test size for each
llm_train, llm_test = train_test_split(llm_data, test_size = 0.2, random_state = 42)
human_train, human_test = train_test_split(human_data, test_size = 0.2, random_state = 42)

# combine the splits back
train_df = pd.concat([llm_train, human_train])
test_df = pd.concat([llm_test, human_test])

# extract embeddings for train and test sets
X_train = model.encode(train_df['Value'].astype('str').tolist())
X_test = model.encode(test_df['Value'].astype('str').tolist())

y_train = train_df['Target']
y_test = test_df['Target']

# Initialize and train the logistic regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = lr_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        80
#            1       1.00      0.40      0.57        20
#
#     accuracy                           0.88       100
#    macro avg       0.93      0.70      0.75       100
# weighted avg       0.90      0.88      0.86       100

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", conf_matrix)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, lr_model.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[80  0]
#  [12  8]]

# %% [markdown]
# ## Time

# %%
csv_files = 'data/ablation_topic_time.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
    
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})
    
new_df = pd.DataFrame(new_rows)

# %%
# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

# separate the data based on the 'target' value
llm_data = new_df[new_df['Target']==0]
human_data = new_df[new_df['Target']==1]

# split each separately, ensuring 20% test size for each
llm_train, llm_test = train_test_split(llm_data, test_size = 0.2, random_state = 42)
human_train, human_test = train_test_split(human_data, test_size = 0.2, random_state = 42)

# combine the splits back
train_df = pd.concat([llm_train, human_train])
test_df = pd.concat([llm_test, human_test])

# extract embeddings for train and test sets
X_train = model.encode(train_df['Value'].astype('str').tolist())
X_test = model.encode(test_df['Value'].astype('str').tolist())

y_train = train_df['Target']
y_test = test_df['Target']

# Initialize and train the logistic regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = lr_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        80
#            1       1.00      0.50      0.67        20
#
#     accuracy                           0.90       100
#    macro avg       0.94      0.75      0.80       100
# weighted avg       0.91      0.90      0.89       100

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", conf_matrix)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, lr_model.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[80  0]
#  [10 10]]

# %% [markdown]
# ## Towels

# %%
csv_files = 'data/ablation_topic_towels.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
    
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})
    
new_df = pd.DataFrame(new_rows)

# %%
# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

# separate the data based on the 'target' value
llm_data = new_df[new_df['Target']==0]
human_data = new_df[new_df['Target']==1]

# split each separately, ensuring 20% test size for each
llm_train, llm_test = train_test_split(llm_data, test_size = 0.2, random_state = 42)
human_train, human_test = train_test_split(human_data, test_size = 0.2, random_state = 42)

# combine the splits back
train_df = pd.concat([llm_train, human_train])
test_df = pd.concat([llm_test, human_test])

# extract embeddings for train and test sets
X_train = model.encode(train_df['Value'].astype('str').tolist())
X_test = model.encode(test_df['Value'].astype('str').tolist())

y_train = train_df['Target']
y_test = test_df['Target']

# Initialize and train the logistic regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = lr_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        80
#            1       1.00      0.60      0.75        20
#
#     accuracy                           0.92       100
#    macro avg       0.95      0.80      0.85       100
# weighted avg       0.93      0.92      0.91       100

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", conf_matrix)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, lr_model.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[80  0]
#  [ 8 12]]

# %% [markdown]
# ## Visualize t-SNE graph

# %%
csv_files = 'data/ablation_topic_froth.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
        
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})

new_df = pd.DataFrame(new_rows)

embeddings = model.encode(new_df['Value'].astype('str').tolist())

tsne = TSNE(n_components = 2, random_state = 30, perplexity = 15)
embeddings_tsne = tsne.fit_transform(embeddings)

# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

# %%
plt.figure(figsize=(10, 6))

# Scatter plot for each class
for target in [0, 1]:
    # Filter rows where 'Target' is equal to the current class (0 or 1)
    indices = new_df['Target'] == target
    plt.scatter(embeddings_tsne[indices, 0], embeddings_tsne[indices, 1], label=f"{'LLM-Generated' if target == 0 else 'Human-Generated'}")

plt.legend()
plt.title('t-SNE visualization of LLM-Generated vs Human-Generated Texts')
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.show()

# %%
csv_files = 'data/ablation_topic_exercise.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
        
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})

new_df = pd.DataFrame(new_rows)

embeddings = model.encode(new_df['Value'].astype('str').tolist())

tsne = TSNE(n_components = 2, random_state = 30, perplexity = 15)
embeddings_tsne = tsne.fit_transform(embeddings)

# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

plt.figure(figsize=(10, 6))

# Scatter plot for each class
for target in [0, 1]:
    # Filter rows where 'Target' is equal to the current class (0 or 1)
    indices = new_df['Target'] == target
    plt.scatter(embeddings_tsne[indices, 0], embeddings_tsne[indices, 1], label=f"{'LLM-Generated' if target == 0 else 'Human-Generated'}")

plt.legend()
plt.title('t-SNE visualization of LLM-Generated vs Human-Generated Texts')
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.show()

# %%
csv_files = 'data/ablation_topic_powder.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
        
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})

new_df = pd.DataFrame(new_rows)

embeddings = model.encode(new_df['Value'].astype('str').tolist())

tsne = TSNE(n_components = 2, random_state = 30, perplexity = 15)
embeddings_tsne = tsne.fit_transform(embeddings)

# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

plt.figure(figsize=(10, 6))

# Scatter plot for each class
for target in [0, 1]:
    # Filter rows where 'Target' is equal to the current class (0 or 1)
    indices = new_df['Target'] == target
    plt.scatter(embeddings_tsne[indices, 0], embeddings_tsne[indices, 1], label=f"{'LLM-Generated' if target == 0 else 'Human-Generated'}")

plt.legend()
plt.title('t-SNE visualization of LLM-Generated vs Human-Generated Texts')
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.show()

# %%
csv_files = 'data/ablation_topic_time.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
        
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})

new_df = pd.DataFrame(new_rows)

embeddings = model.encode(new_df['Value'].astype('str').tolist())

tsne = TSNE(n_components = 2, random_state = 30, perplexity = 15)
embeddings_tsne = tsne.fit_transform(embeddings)

# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

plt.figure(figsize=(10, 6))

# Scatter plot for each class
for target in [0, 1]:
    # Filter rows where 'Target' is equal to the current class (0 or 1)
    indices = new_df['Target'] == target
    plt.scatter(embeddings_tsne[indices, 0], embeddings_tsne[indices, 1], label=f"{'LLM-Generated' if target == 0 else 'Human-Generated'}")

plt.legend()
plt.title('t-SNE visualization of LLM-Generated vs Human-Generated Texts')
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.show()

# %%
csv_files = 'data/ablation_topic_towels.csv'

df = pd.read_csv(csv_files)

# Define the columns for LLM-generated and human-generated
llm_columns = ['zero-shot', 'few-shot', 'novel', 'unique', 'creative', 'critique-critique', 'design-expert', 'farfetched']
human_columns = ['human-1', 'human-2']

new_rows = []
for index, row in df.iterrows():
    for col in llm_columns:
        new_rows.append({'Type': 'LLM-Generated', 'Value': row[col]})
        
    for col in human_columns:
        new_rows.append({'Type': 'human-generated', 'Value': row[col]})

new_df = pd.DataFrame(new_rows)

embeddings = model.encode(new_df['Value'].astype('str').tolist())

tsne = TSNE(n_components = 2, random_state = 30, perplexity = 15)
embeddings_tsne = tsne.fit_transform(embeddings)

# Convert 'Type' into a binary target variable
# LLM-Generated -> 0 & Human-Generated -> 1
new_df['Target'] = new_df['Type'].map({'LLM-Generated': 0, 'human-generated': 1})

plt.figure(figsize=(10, 6))

# Scatter plot for each class
for target in [0, 1]:
    # Filter rows where 'Target' is equal to the current class (0 or 1)
    indices = new_df['Target'] == target
    plt.scatter(embeddings_tsne[indices, 0], embeddings_tsne[indices, 1], label=f"{'LLM-Generated' if target == 0 else 'Human-Generated'}")

plt.legend()
plt.title('t-SNE visualization of LLM-Generated vs Human-Generated Texts')
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.show()
