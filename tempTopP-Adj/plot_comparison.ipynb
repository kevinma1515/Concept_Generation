# %% [markdown]
# # Overview
#
# These all pertain to RQ1. However, in these plots, I am merely analyzing whether using different models has an effect on the trends that are posed when using SentenceBERT.

# %% [markdown]
# ## RoBERTa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# DPP calculations
data = [
    [9, 11, 18, 15, 0, -15, 14, 21, -4, 0],
    [1, 8, 25, 0, 0, -10, 1, -5, -13, 0],
    [44, 50, 110, 88, 73, 14, 84, 75, 16, 0],
    [22, 19, 22, 9, 24, -11, 14, 36, 2, 0],
    [90, 95, 90, 60, 75, 49, 85, 60, 41, 0]
]
# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RoBERTa DPP Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Nearest Generated calculations
data = [
    [-11, -11, -12, -13, -14, -4, -8, -18, 0, 0],
    [-25, -33, -45, -21, -22, -8, -23, -19, 4, 0],
    [-8, -11, -24, -25, -19, -9, -24, -20, 0, 0],
    [-25, -19, -25, -13, -26, -7, -18, -35, -1, 0],
    [-12, -12, -10, -8, -9, -7, -9, -9, -5, 0]
]
# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RoBERTa Nearest Generated Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Convex Hull calculations
data = [
[-80, -80, -83, -87, -92, -55, -69, -94, 24, 0],
[-99, -100, -100, -98, -98, -87, -99, -97, 52, 0],
[-74, -82, -98, -98, -94, -81, -97, -96, -3, 0],
[-99, -97, -99, -92, -99, -71, -95, -100, -16, 0],
[-86, -84, -80, -77, -76, -67, -82, -75, -35, 0]
]


# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RoBERTa Convex Hull Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Centroid Distance calculations
data = [
[-11, -10, -12, -13, -16, -6, -6, -17, 1, 0],
[-26, -36, -46, -24, -24, -12, -24, -22, 2, 0],
[-5, -10, -20, -23, -17, -10, -22, -18, 1, 0],
[-26, -20, -27, -13, -27, -10, -19, -35, -2, 0],
[-9, -7, -6, -5, -7, -7, -6, -8, -3, 0]
]


# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('RoBERTa Centroid Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %% [markdown]
# ## MPNet

# %%
# DPP calculations
data = [
[4, 3, -1, -5, 16, -6, 8, 19, -1, 0],
[31, 15, 37, 15, 18, 13, 12, 15, 2, 0],
[54, 56, 93, 79, 82, 40, 86, 73, 1, 0],
[27, 33, 36, 32, 39, 9, 27, 38, 14, 0],
[66, 74, 67, 41, 46, 39, 61, 39, 27, 0]
]

# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('MPNet DPP Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Nearest Generated calculations
data = [
[-16, -13, -12, -14, -28, -13, -13, -29, -1, 0],
[-31, -31, -41, -28, -27, -20, -25, -26, 3, 0],
[-13, -16, -27, -26, -25, -17, -28, -24, 0, 0],
[-31, -28, -33, -24, -30, -13, -24, -37, 0, 0],
[-12, -12, -11, -7, -9, -7, -11, -8, -5, 0]
]


# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('MPNet Nearest Generated Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Convex Hull calculations
data = [
[-92, -88, -87, -91, -99, -88, -85, -99, 5, 0],
[-100, -100, -100, -99, -99, -97, -99, -99, 84, 0],
[-92, -93, -99, -99, -98, -95, -99, -98, -17, 0],
[-100, -99, -100, -98, -100, -90, -99, -100, 12, 0],
[-84, -82, -82, -72, -78, -57, -83, -72, -39, 0]
]

# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('MPNet Convex Hull Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %%
# Centroid calculations
data = [
[-17, -14, -14, -15, -28, -14, -13, -30, -2, 0],
[-31, -33, -40, -30, -28, -21, -26, -27, 4, 0],
[-12, -14, -25, -25, -23, -17, -27, -23, 0, 0],
[-32, -28, -35, -24, -30, -16, -25, -37, 1, 0],
[-9, -8, -8, -4, -8, -5, -8, -6, -3, 0]
]


# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

plt.figure(figsize=(10, 6))  # Adjust the size as needed
sns.heatmap(data, annot=True, fmt="d", yticklabels=y_labels, xticklabels=x_labels, cmap="YlGnBu")

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set the labels for the axes
plt.xlabel('Parameters')
plt.ylabel('Experiments')

# set the title of the heat map
plt.title('MPNet Centroid Distance Comparison')

# Show the heatmap
plt.tight_layout()  # Adjust layout to fit everything nicely
plt.show()

# %% [markdown]
# ## HeatMap side-by-side

# %%
# DPP
# Generate or load your data
roberta = [
[15, 17, 15, 19, 14, -6, 15, 31, -1, 0],
[30, 43, 80, 25, 23, 0, 30, 18, -10, 0],
[32, 37, 91, 80, 58, 14, 71, 68, 6, 0],
[50, 37, 49, 24, 54, 4, 33, 80, 4, 0],
[65, 65, 54, 39, 43, 24, 50, 35, 25, 0]
]


sentenceTransformer = [
[38, 40, 38, 40, 30, 11, 35, 38, 0, 0],
[74, 64, 106, 74, 63, 30, 71, 50, -3, 0],
[49, 49, 75, 53, 72, 35, 97, 78, 0, 0],
[60, 40, 68, 36, 49, 8, 32, 84, 1, 0],
[49, 52, 42, 30, 26, 11, 43, 26, 10, 0]
]


mpnet = [
[17, 13, 11, 13, 42, 8, 14, 48, -3, 0],
[55, 41, 79, 44, 41, 22, 34, 34, -3, 0],
[38, 47, 86, 74, 69, 33, 75, 70, 2, 0],
[58, 53, 65, 46, 63, 18, 42, 74, 3, 0],
[52, 58, 49, 32, 38, 22, 50, 31, 18, 0]
]

# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# Plot the heatmaps
sns.heatmap(roberta, ax=ax1, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(sentenceTransformer, ax=ax2, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(mpnet, ax=ax3, cbar=True, xticklabels = x_labels, yticklabels = y_labels)

# Optionally, adjust the layout and add titles
ax1.set_title('RoBERTa DPP')
ax2.set_title('SentenceBERT DPP')
ax3.set_title('MPNet DPP')

ax1.set_xlabel('Parameters')
ax1.set_ylabel('Design Topics')
ax2.set_xlabel('Parameters')
ax2.set_ylabel('Design Topics')
ax3.set_xlabel('Parameters')
ax3.set_ylabel('Design Topics')

plt.tight_layout()
plt.show()

# %%
# Nearest Generated
roberta = [
    [-11, -11, -12, -13, -14, -4, -8, -18, 0, 0],
    [-25, -33, -45, -21, -22, -8, -23, -19, 4, 0],
    [-8, -11, -24, -25, -19, -9, -24, -20, 0, 0],
    [-25, -19, -25, -13, -26, -7, -18, -35, -1, 0],
    [-12, -12, -10, -8, -9, -7, -9, -9, -5, 0]
]

sentenceTransformer = [
    [-18, -19, -19, -21, -20, -12, -15, -21, -2, 0],
    [-38, -38, -48, -36, -33, -24, -35, -31, 3, 0],
    [-14, -14, -20, -18, -23, -16, -30, -22, 1, 0],
    [-26, -18, -27, -17, -19, -7, -16, -34, 0, 0],
    [-9, -8, -7, -4, -5, -4, -7, -5, -2, 0]
]

mpnet = [
[-16, -13, -12, -14, -28, -13, -13, -29, -1, 0],
[-31, -31, -41, -28, -27, -20, -25, -26, 3, 0],
[-13, -16, -27, -26, -25, -17, -28, -24, 0, 0],
[-31, -28, -33, -24, -30, -13, -24, -37, 0, 0],
[-12, -12, -11, -7, -9, -7, -11, -8, -5, 0]
]

# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# Plot the heatmaps
sns.heatmap(roberta, ax=ax1, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(sentenceTransformer, ax=ax2, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(mpnet, ax=ax3, cbar=True, xticklabels = x_labels, yticklabels = y_labels)

# Optionally, adjust the layout and add titles
ax1.set_title('RoBERTa Nearest')
ax2.set_title('SentenceBERT Nearest')
ax3.set_title('MPNet Nearest')

ax1.set_xlabel('Parameters')
ax1.set_ylabel('Design Topics')
ax2.set_xlabel('Parameters')
ax2.set_ylabel('Design Topics')
ax3.set_xlabel('Parameters')
ax3.set_ylabel('Design Topics')

plt.tight_layout()
plt.show()

# %%
# Convex Hull

roberta = [
[-80, -80, -83, -87, -92, -55, -69, -94, 24, 0],
[-99, -100, -100, -98, -98, -87, -99, -97, 52, 0],
[-74, -82, -98, -98, -94, -81, -97, -96, -3, 0],
[-99, -97, -99, -92, -99, -71, -95, -100, -16, 0],
[-86, -84, -80, -77, -76, -67, -82, -75, -35, 0]
]

sentenceTransformer = [
    [-94, -94, -94, -96, -97, -88, -87, -97, -34, 0],
    [-100, -100, -100, -100, -100, -98, -100, -100, 26, 0],
    [-93, -91, -96, -96, -98, -95, -99, -97, -12, 0],
    [-99, -96, -99, -94, -96, -72, -94, -100, 32, 0],
    [-74, -68, -67, -37, -57, -46, -66, -63, -19, 0]
]

mpnet = [
[-92, -88, -87, -91, -99, -88, -85, -99, 5, 0],
[-100, -100, -100, -99, -99, -97, -99, -99, 84, 0],
[-92, -93, -99, -99, -98, -95, -99, -98, -17, 0],
[-100, -99, -100, -98, -100, -90, -99, -100, 12, 0],
[-84, -82, -82, -72, -78, -57, -83, -72, -39, 0]
]

# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# Plot the heatmaps
sns.heatmap(roberta, ax=ax1, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(sentenceTransformer, ax=ax2, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(mpnet, ax=ax3, cbar=True, xticklabels = x_labels, yticklabels = y_labels)

# Optionally, adjust the layout and add titles
ax1.set_title('RoBERTa Convex Hull')
ax2.set_title('SentenceBERT Convex Hull')
ax3.set_title('MPNet Convex Hull')

ax1.set_xlabel('Parameters')
ax1.set_ylabel('Design Topics')
ax2.set_xlabel('Parameters')
ax2.set_ylabel('Design Topics')
ax3.set_xlabel('Parameters')
ax3.set_ylabel('Design Topics')

plt.tight_layout()
plt.show()

# %%
# Centroid

roberta = [
[-11, -10, -12, -13, -16, -6, -6, -17, 1, 0],
[-26, -36, -46, -24, -24, -12, -24, -22, 2, 0],
[-5, -10, -20, -23, -17, -10, -22, -18, 1, 0],
[-26, -20, -27, -13, -27, -10, -19, -35, -2, 0],
[-9, -7, -6, -5, -7, -7, -6, -8, -3, 0]
]


sentenceTransformer = [
    [-17, -18, -18, -21, -22, -12, -12, -21, -3, 0],
    [-38, -40, -48, -36, -33, -27, -34, -33, 2, 0],
    [-12, -13, -17, -18, -22, -17, -30, -21, 1, 0],
    [-26, -18, -27, -16, -18, -8, -17, -34, 1, 0],
    [-5, -4, -3, -1, -3, -3, -3, -3, -1, 0]
]

mpnet = [
[-17, -14, -14, -15, -28, -14, -13, -30, -2, 0],
[-31, -33, -40, -30, -28, -21, -26, -27, 4, 0],
[-12, -14, -25, -25, -23, -17, -27, -23, 0, 0],
[-32, -28, -35, -24, -30, -16, -25, -37, 1, 0],
[-9, -8, -8, -4, -8, -5, -8, -6, -3, 0]
]


# Custom y-axis labels
x_labels = [
    'TopP=0|Temperature=0',
    'TopP=0.5|Temperature=0',
    'TopP=1|Temperature=0',
    'TopP=0|Temperature=1',
    'TopP=0.5|Temperature=1',
    'TopP=1|Temperature=1',
    'TopP=0|Temperature=2',
    'TopP=0.5|Temperature=2',
    'Human 50 v1',
    'Human 50 v2'
]

# x-axis labels
y_labels = ['froth', 'towels', 'time', 'powder', 'exercise']

# Create a figure with three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# Plot the heatmaps
sns.heatmap(roberta, ax=ax1, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(sentenceTransformer, ax=ax2, cbar=False, xticklabels = x_labels, yticklabels = y_labels)
sns.heatmap(mpnet, ax=ax3, cbar=True, xticklabels = x_labels, yticklabels = y_labels)

# Optionally, adjust the layout and add titles
ax1.set_title('RoBERTa Centroid Distance')
ax2.set_title('SentenceBERT Centroid Distance')
ax3.set_title('MPNet Centroid Distance')

ax1.set_xlabel('Parameters')
ax1.set_ylabel('Design Topics')
ax2.set_xlabel('Parameters')
ax2.set_ylabel('Design Topics')
ax3.set_xlabel('Parameters')
ax3.set_ylabel('Design Topics')

plt.tight_layout()
plt.show()
